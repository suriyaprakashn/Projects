# %%
import pandas as pd
import numpy as np
data1=pd.read_csv("fifa_ variable_information.csv")

# %%
data=pd.read_csv('fifa.csv')

# %%
data.describe()
# Out:
#                   ID           Age       Overall     Potential  \
# count   18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299
# std     29965.244204      4.669943      6.908930      6.136496
# min        16.000000     16.000000     46.000000     48.000000
# 25%    200315.500000     21.000000     62.000000     67.000000
# 50%    221759.000000     25.000000     66.000000     71.000000
# 75%    236529.500000     28.000000     71.000000     75.000000
# max    246620.000000     45.000000     94.000000     95.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# std                    0.394031      0.660456      0.756164      15.947765
# min                    1.000000      1.000000      1.000000       1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 60 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Preferred Foot            18159 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# Crossing                       48
# Finishing                      48
# ...

# %%
data
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
num_data=data.select_dtypes(include=np.number)
cat_data=data.select_dtypes(exclude=np.number)

# %%
num_data
# Out:
#            ID  Age  Overall  Potential  International Reputation  Weak Foot  \
# 0      158023   31       94         94                       5.0        4.0
# 1       20801   33       94         94                       5.0        4.0
# 2      190871   26       92         93                       5.0        5.0
# 3      193080   27       91         93                       4.0        3.0
# 4      192985   27       91         92                       4.0        5.0
# ...       ...  ...      ...        ...                       ...        ...
# 18202  238813   19       47         65                       1.0        2.0
# 18203  243165   19       47         63                       1.0        2.0
# 18204  241638   16       47         67                       1.0        3.0
# 18205  246268   17       47         66                       1.0        3.0
# 18206  246269   16       46         66                       1.0        3.0
#
# ...

# %%
cat_data
# Out:
#                      Name                                           Photo  \
# 0                L. Messi  https://cdn.sofifa.org/players/4/19/158023.png
# 1       Cristiano Ronaldo   https://cdn.sofifa.org/players/4/19/20801.png
# 2               Neymar Jr  https://cdn.sofifa.org/players/4/19/190871.png
# 3                  De Gea  https://cdn.sofifa.org/players/4/19/193080.png
# 4            K. De Bruyne  https://cdn.sofifa.org/players/4/19/192985.png
# ...                   ...                                             ...
# 18202        J. Lundstram  https://cdn.sofifa.org/players/4/19/238813.png
# 18203  N. Christoffersson  https://cdn.sofifa.org/players/4/19/243165.png
# 18204           B. Worman  https://cdn.sofifa.org/players/4/19/241638.png
# 18205      D. Walker-Rice  https://cdn.sofifa.org/players/4/19/246268.png
# 18206           G. Nugent  https://cdn.sofifa.org/players/4/19/246269.png
#
#       Nationality                                 Flag                 Club  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.drop(columns='Loaned From',axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# ID                             0
# Name                           0
# Age                            0
# Photo                          0
# Nationality                    0
# Flag                           0
# Overall                        0
# Potential                      0
# Club                         241
# Club Logo                      0
# Value                          0
# Wage                           0
# Preferred Foot                48
# International Reputation      48
# Weak Foot                     48
# Skill Moves                   48
# Work Rate                     48
# Body Type                     48
# Position                      60
# Jersey Number                 60
# Joined                      1553
# Contract Valid Until         289
# Height                        48
# Weight                        48
# Crossing                      48
# Finishing                     48
# HeadingAccuracy               48
# ShortPassing                  48
# ...

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data1
# Out:
#                           ID          unique id for every player
# 0                       Name                                name
# 1                        Age                                 age
# 2                      Photo           url to the player's photo
# 3                Nationality                         nationality
# 4                       Flag       url to players's country flag
# 5                    Overall                      overall rating
# 6                  Potential                    potential rating
# 7                       Club                        current club
# 8                  Club Logo                    url to club logo
# 9                      Value                current market value
# 10                      Wage                        current wage
# 11            Preferred Foot                          left/right
# 12  International Reputation                rating on scale of 5
# ...

# %%
data['Age'].to_frame()
# Out:
#        Age
# 0       31
# 1       33
# 2       26
# 3       27
# 4       27
# ...    ...
# 18202   19
# 18203   19
# 18204   16
# 18205   17
# 18206   16
#
# [18207 rows x 1 columns]

# %%
data[data['Value'].str.contains('M')]
# Out:
#            ID               Name  Age  \
# 0      158023           L. Messi   31
# 1       20801  Cristiano Ronaldo   33
# 2      190871          Neymar Jr   26
# 3      193080             De Gea   27
# 4      192985       K. De Bruyne   27
# ...       ...                ...  ...
# 11323  239948           S. Reyes   20
# 11457  241266        W. Geubbels   16
# 11566  229516            Mayoral   21
# 11682  232104           D. James   20
# 11835  225738       Kuki Zalazar   20
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
def conversion(i):
    if i == np.NaN:
        return np.NaN
    elif type(i) == float:
        return i
    
    if i[-1]=='M':
        return float(i[:-1])*1000000
    elif i[-1]=='K':
        return float(i[:-1])*1000
    return i

# %%
data['Value']=data['Value'].str.strip('€').apply(conversion).astype(np.number)

# %%
data['Release Clause']=data['Release Clause'].str.strip('€').apply(conversion).astype(np.number)

# %%
data['Wage']=data['Wage'].str.strip('€').apply(conversion).astype(np.number)

# %%
data['Value']
# Out:
# 0        110500000.0
# 1         77000000.0
# 2        118500000.0
# 3         72000000.0
# 4        102000000.0
#             ...
# 18202        60000.0
# 18203        60000.0
# 18204        60000.0
# 18205        60000.0
# 18206        60000.0
# Name: Value, Length: 18207, dtype: float64

# %%
data['Joined']=pd.to_datetime(data['Joined'])
data['Joined'] = pd.DatetimeIndex(data['Joined']).year

# %%
data['Joined'].astype('object')
# Out:
# 0        2004.0
# 1        2018.0
# 2        2017.0
# 3        2011.0
# 4        2015.0
#           ...
# 18202    2017.0
# 18203    2018.0
# 18204    2017.0
# 18205    2018.0
# 18206    2018.0
# Name: Joined, Length: 18207, dtype: object

# %%
data['Joined']
# Out:
# 0        2004.0
# 1        2018.0
# 2        2017.0
# 3        2011.0
# 4        2015.0
#           ...
# 18202    2017.0
# 18203    2018.0
# 18204    2017.0
# 18205    2018.0
# 18206    2018.0
# Name: Joined, Length: 18207, dtype: float64

# %%
data['Contract Valid Until']=pd.to_datetime(data['Contract Valid Until'])

# %%
data['Contract Valid Until']
# Out:
# 0       2021-01-01
# 1       2022-01-01
# 2       2022-01-01
# 3       2020-01-01
# 4       2023-01-01
#            ...
# 18202   2019-01-01
# 18203   2020-01-01
# 18204   2021-01-01
# 18205   2019-01-01
# 18206   2019-01-01
# Name: Contract Valid Until, Length: 18207, dtype: datetime64[ns]

# %%
data['Height'].to_frame()
# Out:
#       Height
# 0        5'7
# 1        6'2
# 2        5'9
# 3        6'4
# 4       5'11
# ...      ...
# 18202    5'9
# 18203    6'3
# 18204    5'8
# 18205   5'10
# 18206   5'10
#
# [18207 rows x 1 columns]

# %%
def height(h):
    try:
        return int(h[0])*30.48+(int(h[1])*2.54)
    except:
        return np.NaN
def weight(w):
    try:
        return int(w)/2.205
    except:
        return np.NaN

# %%
data['Height']=data['Height'].str.split("'").apply(height).round()

# %%
data['Weight']=data['Weight'].str.strip('lbs').apply(weight).round()

# %%
data['Weight']
# Out:
# 0        72.0
# 1        83.0
# 2        68.0
# 3        76.0
# 4        70.0
#          ...
# 18202    61.0
# 18203    77.0
# 18204    67.0
# 18205    70.0
# 18206    80.0
# Name: Weight, Length: 18207, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 59 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  float64
#  11  Wage                      18207 non-null  float64
#  12  Preferred Foot            18159 non-null  object
# ...

# %%
data
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
data[data['Club'].isnull()].index
# Out:
# Int64Index([  452,   538,   568,   677,   874,   953,   997,  1008,  1120,
#              1271,
#             ...
#             16903, 16947, 16976, 17008, 17129, 17197, 17215, 17339, 17436,
#             17539],
#            dtype='int64', length=241)

# %% [markdown]
# ## mean imputation

# %%
num_data.isnull().sum()/len(num_data)*100
# Out:
# ID                          0.000000
# Age                         0.000000
# Overall                     0.000000
# Potential                   0.000000
# International Reputation    0.263635
# Weak Foot                   0.263635
# Skill Moves                 0.263635
# Jersey Number               0.329544
# Crossing                    0.263635
# Finishing                   0.263635
# HeadingAccuracy             0.263635
# ShortPassing                0.263635
# Volleys                     0.263635
# Dribbling                   0.263635
# Curve                       0.263635
# FKAccuracy                  0.263635
# LongPassing                 0.263635
# BallControl                 0.263635
# Acceleration                0.263635
# SprintSpeed                 0.263635
# Agility                     0.263635
# Reactions                   0.263635
# Balance                     0.263635
# ShotPower                   0.263635
# Jumping                     0.263635
# ...

# %%
data[i].fillna(data[i].median())
# Out:
# 0        72.0
# 1        83.0
# 2        68.0
# 3        76.0
# 4        70.0
#          ...
# 18202    61.0
# 18203    77.0
# 18204    67.0
# 18205    70.0
# 18206    80.0
# Name: Weight, Length: 18207, dtype: float64

# %%
mean_impu=['GKReflexes','GKPositioning','GKKicking','GKHandling','GKDiving','SlidingTackle','StandingTackle','Marking','Composure'
          ,'Penalties','Vision','Positioning','Interceptions','Aggression','LongShots','Strength','Stamina','Jumping','Weak Foot'
          ,'ShotPower','Balance','Reactions','Agility','SprintSpeed','Acceleration','BallControl','LongPassing','FKAccuracy','Curve'
          ,'Dribbling','Volleys','ShortPassing','HeadingAccuracy','Finishing','Crossing','Jersey Number','Skill Moves','Weak Foot','International Reputation']

# %%
len(mean_impu)
# Out:
# 39

# %%
for i in mean_impu:
    q3=data[i].quantile(.75)
    q1=data[i].quantile(.25)
    iqr=q3-q1
    print(i,iqr)
    ub=q3+1.5*iqr
    lb=q1-1.5*iqr

    outlier_data=num_data[(data[i]>ub)|(num_data[i]<lb)]
    per_outliers=len(outlier_data)/len(data)*100
    print('the number of outliers in the',i,'column is',per_outliers>0)
# Out:
# GKReflexes 6.0
# the number of outliers in the GKReflexes column is True
# GKPositioning 6.0
# the number of outliers in the GKPositioning column is True
# GKKicking 6.0
# the number of outliers in the GKKicking column is True
# GKHandling 6.0
# the number of outliers in the GKHandling column is True
# GKDiving 6.0
# the number of outliers in the GKDiving column is True
# SlidingTackle 40.0
# the number of outliers in the SlidingTackle column is False
# StandingTackle 39.0
# the number of outliers in the StandingTackle column is False
# Marking 34.0
# the number of outliers in the Marking column is False
# Composure 16.0
# the number of outliers in the Composure column is True
# Penalties 21.0
# the number of outliers in the Penalties column is True
# Vision 20.0
# the number of outliers in the Vision column is True
# Positioning 26.0
# the number of outliers in the Positioning column is False
# Interceptions 38.0
# the number of outliers in the Interceptions column is False
# ...

# %%
cat_data.isnull().sum()
# Out:
# Name                        0
# Photo                       0
# Nationality                 0
# Flag                        0
# Club                      241
# Club Logo                   0
# Value                       0
# Wage                        0
# Preferred Foot             48
# Work Rate                  48
# Body Type                  48
# Position                   60
# Joined                   1553
# Loaned From             16943
# Contract Valid Until      289
# Height                     48
# Weight                     48
# Release Clause           1564
# dtype: int64

# %%
data['Club'].fillna(data['Club'].mode(),inplace=True)

# %%
data['Club'].ffill(inplace=True)

# %%
data['Joined'].fillna(value=int(data.Joined.mean()),inplace=True)

# %%
data['Joined'] = data['Joined'].astype('int64')

# %%
data['Release Clause'].fillna(value=int(data['Release Clause'].mean()),inplace=True)

# %%
data['Contract Valid Until'].fillna(value=pd.to_datetime(data['Contract Valid Until'].mean().date()),inplace=True)

# %%
data['Position'].fillna(data['Position'].mode()[0],inplace=True)

# %%
data['Jersey Number'].fillna(data['Jersey Number'].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# ID                           0
# Name                         0
# Age                          0
# Photo                        0
# Nationality                  0
# Flag                         0
# Overall                      0
# Potential                    0
# Club                         0
# Club Logo                    0
# Value                        0
# Wage                         0
# Preferred Foot              48
# International Reputation    48
# Weak Foot                   48
# Skill Moves                 48
# Work Rate                   48
# Body Type                   48
# Position                     0
# Jersey Number                0
# Joined                       0
# Contract Valid Until         0
# Height                      48
# Weight                      48
# Crossing                    48
# Finishing                   48
# HeadingAccuracy             48
# ShortPassing                48
# Volleys                     48
# Dribbling                   48
# ...

# %%
for i in mean_impu:
    data[i]=data[i].fillna(data[i].mean())

# %%
data['Height'].isnull().sum()
# Out:
# 48

# %%
miss2=['Preferred Foot','Work Rate','Body Type','Height','Weight']

# %%
for i in miss2:
    data[i]=data[i].fillna(data[i].mode()[0])

# %%
data['Height'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
## selecting numer data type columns and categorical 
num_data=data.select_dtypes(include=np.number)
cat_data=data.select_dtypes(exclude=np.number)

# %% [markdown]
# ## dist plot

# %%
sns.distplot(data['Overall'])
plt.xlabel('overall rating')
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plot=['Overall','Value','Wage','International Reputation','Height','Weight','Release Clause']
sns.pairplot(data[plot])

# %%
expire=data[data['Contract Valid Until']<'2020'].sort_values('Overall',ascending=False)
expire['Overall_Rank'] = expire[['Overall','Value']].apply(tuple,axis=1).rank(ascending=False,method='min')

# %%
pd.DataFrame(expire.sort_values(by=['Overall','Value'],ascending=False)['Overall'].rank(ascending=False,method='first'))
data.iloc[[12,  28,  38,  41,  51,  86,  94],:]
# Out:
#           ID          Name  Age  \
# 130   192629    Iago Aspas   30
# 362   200454  Paco Alcácer   24
# 499   189805    L. de Jong   27
# 511   186537     C. Stuani   31
# 653   196978     C. Wilson   26
# 1116  213432   F. Ferreyra   27
# 1022  185195     O. Ighalo   29
#
#                                                Photo  Nationality  \
# 130   https://cdn.sofifa.org/players/4/19/192629.png        Spain
# 362   https://cdn.sofifa.org/players/4/19/200454.png        Spain
# 499   https://cdn.sofifa.org/players/4/19/189805.png  Netherlands
# 511   https://cdn.sofifa.org/players/4/19/186537.png      Uruguay
# 653   https://cdn.sofifa.org/players/4/19/196978.png      England
# 1116  https://cdn.sofifa.org/players/4/19/213432.png    Argentina
# 1022  https://cdn.sofifa.org/players/4/19/185195.png      Nigeria
#
#                                       Flag  Overall  Potential  \
# 130    https://cdn.sofifa.org/flags/45.png       84         84
# ...

# %% [markdown]
# ## top 20 players

# %%
expire = expire[expire['Overall_Rank'] <= 20]

# %%
expire[['Name','Value','Overall_Rank']].sort_values('Overall_Rank').head(6)
# Out:
#              Name       Value  Overall_Rank
# 12       D. Godín  44000000.0           1.0
# 28   J. Rodríguez  69500000.0           2.0
# 38     G. Higuaín  57000000.0           3.0
# 41      G. Buffon   4000000.0           4.0
# 51  J. Vertonghen  34000000.0           5.0
# 86           Koke  45000000.0           6.0

# %% [markdown]
# ## avgwage

# %%
sns.distplot(expire['Wage'])
plt.axvline(expire['Wage'].mean())
expire['Wage'].mean()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 127750.0

# %% [markdown]
# ## avg age

# %%
sns.distplot(expire['Age'])
plt.axvline(expire['Age'].mean())
expire['Age'].mean()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 29.6

# %% [markdown]
# ## relation btween Overall and value

# %%
expire[['Overall','Value']].corr()
# overall and value as medium positive corelation
# Out:
#           Overall     Value
# Overall  1.000000  0.340731
# Value    0.340731  1.000000

# %%
sns.heatmap(expire[['Overall','Value']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.head(30)
# Out:
#         ID               Name  Age  \
# 0   158023           L. Messi   31
# 1    20801  Cristiano Ronaldo   33
# 2   190871          Neymar Jr   26
# 3   193080             De Gea   27
# 4   192985       K. De Bruyne   27
# 5   183277          E. Hazard   27
# 6   177003          L. Modrić   32
# 7   176580          L. Suárez   31
# 8   155862       Sergio Ramos   32
# 9   200389           J. Oblak   25
# 10  188545     R. Lewandowski   29
# 11  182521           T. Kroos   28
# 12  182493           D. Godín   32
# 13  168542        David Silva   32
# 14  215914           N. Kanté   27
# 15  211110          P. Dybala   24
# 16  202126            H. Kane   24
# 17  194765       A. Griezmann   27
# 18  192448      M. ter Stegen   26
# 19  192119        T. Courtois   26
# 20  189511    Sergio Busquets   29
# 21  179813          E. Cavani   31
# 22  167495           M. Neuer   32
# 23  153079          S. Agüero   30
# 24  138956       G. Chiellini   33
# ...

# %% [markdown]
# ## top 5 players in each position

# %%
data = data.sort_values(by=['Position','Overall','Value'],ascending=False)
data['Overall_Position_Rank'] = data.groupby('Position')['Overall'].rank(ascending=False,method='first')

# %%
posi=data[data['Overall_Position_Rank']<6]

# %% [markdown]
# ## repeated players in every position

# %%
posi[posi['ID'].duplicated()]
## ther is no players repeated in each position
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause, Overall_Position_Rank]
# Index: []
#
# [0 rows x 60 columns]

# %%
posi.groupby('Position').agg({'Wage':np.mean})
# Out:
#               Wage
# Position
# CAM       174000.0
# CB        166000.0
# CDM       217000.0
# CF         47400.0
# CM        130600.0
# GK        192800.0
# LAM        81600.0
# LB        177200.0
# LCB       162000.0
# LCM       203000.0
# LDM       126600.0
# LF        123200.0
# LM        164600.0
# LS        130200.0
# LW        261000.0
# LWB        33000.0
# RAM        45400.0
# RB        155400.0
# RCB       229000.0
# RCM       240800.0
# RDM       105000.0
# RF        148000.0
# RM        131400.0
# RS        132200.0
# RW        202000.0
# RWB        44200.0
# ST        294000.0

# %%
data.iloc[452]
# Out:
# ID                                                                  207439
# Name                                                            L. Paredes
# Age                                                                     24
# Photo                       https://cdn.sofifa.org/players/4/19/207439.png
# Nationality                                                      Argentina
# Flag                                   https://cdn.sofifa.org/flags/52.png
# Overall                                                                 80
# Potential                                                               85
# Club                                                               Everton
# Club Logo                              https://cdn.sofifa.org/flags/52.png
# Value                                                                  0.0
# Wage                                                                   0.0
# ...

# %%
data.to_csv('data2.csv',index=False)

# %%
data['Overall']
# Out:
# 1        94
# 10       90
# 16       89
# 23       89
# 36       88
#          ..
# 18144    49
# 18121    49
# 18138    49
# 18170    48
# 18171    48
# Name: Overall, Length: 18207, dtype: int64

# %%
data1
# Out:
#                           ID          unique id for every player
# 0                       Name                                name
# 1                        Age                                 age
# 2                      Photo           url to the player's photo
# 3                Nationality                         nationality
# 4                       Flag       url to players's country flag
# 5                    Overall                      overall rating
# 6                  Potential                    potential rating
# 7                       Club                        current club
# 8                  Club Logo                    url to club logo
# 9                      Value                current market value
# 10                      Wage                        current wage
# 11            Preferred Foot                          left/right
# 12  International Reputation                rating on scale of 5
# ...
